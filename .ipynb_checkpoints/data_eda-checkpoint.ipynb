# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                Job Title                                    Salary Estimate  \
# 0  People Data Scientist             Employer Provided Salary:$141K - $186K
# 1         Data Scientist              Employer Provided Salary:$80K - $120K
# 2         Data Scientist  Employer Provided Salary:$50.00 - $60.00 Per Hour
# 3  Junior Data Scientist               Employer Provided Salary:$55K - $60K
# 4         Data Scientist  Employer Provided Salary:$32.00 - $42.00 Per Hour
#
#                                      Job Description  Rating  \
# 0  Who we are:\nlululemon is a yoga-inspired tech...     2.9
# 1  Meet MedPro Group. We’re an industry-leading B...     2.9
# 2  Resume should have education details along wit...     2.9
# 3  Brookfield, WI, USA\nSummary:\nHiring Fresher ...     2.9
# 4  Data Scientist responsibilities include:\nData...     2.9
#
#            Company Name        Location Headquarters  \
# 0        Lululemon\n4.3     Seattle, WA           -1
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'python_yn', 'r_yn', 'spark',
#        'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    673
# na                 72
# mle                14
# analyst            11
# data engineer       5
# director            1
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        649
# senior    114
# jr         13
# Name: seniority, dtype: int64

# %%
#Fix states without an acronym
"""
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'United States' else 'USA')
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Manhattan' else 'MHTN')
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Pennsylvania' else 'PA')
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Texas' else 'TX')
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'South Carolina' else 'SC')
df['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Colorado' else 'CO')
"""
# Out:
# "\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'United States' else 'USA')\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Manhattan' else 'MHTN')\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Pennsylvania' else 'PA')\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Texas' else 'TX')\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'South Carolina' else 'SC')\ndf['job_state'] = df.job_state.apply(lambda x: str(x).strip() if str(x).strip().lower() != 'Colorado' else 'CO')\n"

# %%
df.job_state.value_counts()
# Out:
#  CA               138
# Remote             78
#  NY                73
#  MA                52
#  TX                50
#  VA                45
#  PA                28
#  MD                28
# -1                 25
#  IL                24
#  WA                23
#  FL                23
#  CO                19
#  NJ                18
#  NC                16
#  MI                15
#  GA                12
#  DC                11
# United States      11
#  OH                 8
#  NM                 7
#  DE                 6
#  MO                 6
#  UT                 5
#  AZ                 5
#  WV                 4
#  CT                 4
#  MN                 4
#  MS                 3
#  OR                 3
#  WI                 3
#  AR                 2
#  IA                 2
#  AL                 2
#  ME                 2
#  KY                 2
#  RI                 2
#  TN                 2
#  LA                 1
# Manhattan           1
# Pennsylvania        1
# ...

# %%
#Job descripiton Length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2613
# 1      5209
# 2       597
# 3       662
# 4       413
#        ...
# 771    1178
# 772    1189
# 773    1049
# 774       2
# 775    1008
# Name: desc_len, Length: 776, dtype: int64

# %%
#Competitors don't exist in this dataset

# %%
#hourly wage to anual

df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis = 1)
df[df.hourly == 1][['hourly','min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 2         1         100         120
# 4         1          64          84
# 5         1         130         150
# 7         1          68          68
# 9         1         120         144
# ..      ...         ...         ...
# 651       1         120         120
# 676       1         120         120
# 712       1         120         120
# 739       1         120         120
# 766       1         120         120
#
# [65 rows x 3 columns]

# %%
df['company_txt'] = df.company_txt.apply(lambda x: str(x).replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0                                   Lululemon
# 1                                MedPro Group
# 2                                 zettalogix.
# 3                                      Augray
# 4                           Ingress IT Soluti
#                         ...
# 771                            Analog Devices
# 772    US Employment and Training Administrat
# 773                      Siemens Healthineers
# 774                                       nan
# 775                             UMASS Medical
# Name: company_txt, Length: 776, dtype: object

# %%
df.describe()
# Out:
#            Rating      hourly  employer_provided  min_salary  max_salary  \
# count  776.000000  776.000000         776.000000  776.000000  776.000000
# mean     2.996134    0.083763           0.501289   96.795103  135.529639
# std      1.865859    0.277211           0.500321   30.834468   41.102850
# min     -1.000000    0.000000           0.000000    4.000000    6.000000
# 25%      3.100000    0.000000           0.000000   78.000000  110.000000
# 50%      3.600000    0.000000           1.000000   89.000000  128.000000
# 75%      4.100000    0.000000           1.000000  110.000000  154.250000
# max      5.000000    1.000000           1.000000  248.000000  314.000000
#
#        avg_salary  same_state   python_yn        r_yn       spark         aws  \
# count  776.000000  776.000000  776.000000  776.000000  776.000000  776.000000
# mean   110.951031    0.372423    0.123711    0.001289    0.037371    0.034794
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'python_yn', 'r_yn', 'spark',
#        'aws', 'excel', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most of data science jobs are rated in 3.

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The most avarage salary is about to 100

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['avg_salary', 'Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['Rating'])
# Out:
# <AxesSubplot:>

# %%
df[['avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#             avg_salary    Rating  desc_len
# avg_salary    1.000000  0.043786  0.168712
# Rating        0.043786  1.000000 -0.017359
# desc_len      0.168712 -0.017359  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['avg_salary','Rating','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Looks like that has a correlation with the desc_len (description length) with the avg_salary (avarage salary) and also a minor correlation with Rating with the avg_salary, I don't exact know why but if I have to guess I'll guess that companies that pay more also are more interested in contract because of this they elabore a more detailed description of the job. Also, I can imagina that the rating is because people who work/worked in that company rate the company using the salary as base of his judgement.

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'python_yn', 'r_yn', 'spark',
#        'aws', 'excel', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python_yn', 'r_yn',
       'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" %(i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 222
# graph for Headquarters: total = 129
# graph for Size: total = 9
# graph for Type of ownership: total = 142
# graph for Industry: total = 42
# graph for Sector: total = 83
# graph for Revenue: total = 32
# graph for company_txt: total = 540
# graph for job_state: total = 51
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for r_yn: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 6
# graph for seniority: total = 3

# %%
for i in df_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" %(i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'python_yn', 'r_yn', 'spark',
#        'aws', 'excel', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          99.545455
# data engineer   115.600000
# data scientist  111.219168
# director        180.000000
# mle             132.071429
# na              104.798611

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na          36.750000
#                senior     113.500000
# data engineer  na         112.166667
#                senior     120.750000
# data scientist jr          84.083333
#                na         106.405018
#                senior     140.461165
# director       na         180.000000
# mle            na         132.071429
# na             jr          36.500000
#                na         105.760563

# %%
pd.pivot_table(df, index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                 avg_salary
# job_state
# South Carolina  155.000000
#  NY             143.547945
#  SC             139.000000
#  CA             128.380435
#  WA             127.195652
#  NM             121.500000
#  RI             118.000000
# Manhattan       112.500000
#  WV             111.500000
#  HI             109.000000
# -1              108.680000
#  PA             107.982143
#  CT             107.375000
#  VA             106.444444
#  DC             105.636364
#  MA             105.326923
# Pennsylvania    105.000000
#  AL             105.000000
#  AR             104.500000
#  GA             104.458333
#  MD             104.053571
#  OR             103.666667
#  AZ             103.400000
# Remote          102.935897
#  TN             102.500000
#  IL             102.479167
#  FL             102.304348
#  KS             101.000000
#  IN             101.000000
# United States    99.863636
#  CO              98.315789
#  TX              97.350000
#  NC              96.968750
# ...

# %%
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                                avg_salary
# job_state      job_simp
# United States  data scientist          11
# Texas          na                       1
# South Carolina data scientist           1
# Remote         director                 1
#                data engineer            2
# ...                                   ...
#  CA            mle                      2
#                na                      17
#  AZ            data scientist           5
#  AR            data scientist           2
#  AL            data scientist           2
#
# [79 rows x 1 columns]

# %%
#pd.set_option('display.max_rows', None) #To display all rows of the cell above.

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = ['job_state', 'job_simp'], values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                                avg_salary
# job_state      job_simp
# South Carolina data scientist  155.000000
#  NY            data scientist  142.709677
#  SC            data scientist  139.000000
#  CA            data scientist  129.929204
#  WA            data scientist  129.025000
#  NM            data scientist  121.500000
#  RI            data scientist  118.000000
# Manhattan      data scientist  112.500000
#  WV            data scientist  111.500000
#  VA            data scientist  109.464286
#  HI            data scientist  109.000000
#  GA            data scientist  108.727273
#  CT            data scientist  107.375000
#  MA            data scientist  106.293478
#  PA            data scientist  106.180000
#  DC            data scientist  105.636364
#  MD            data scientist  105.370370
#  AL            data scientist  105.000000
# Pennsylvania   data scientist  105.000000
#  AR            data scientist  104.500000
#  OR            data scientist  103.666667
# ...

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided', 'python_yn', 'r_yn', 'spark', 'aws', 'excel', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values='avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  4.0    126.519231
#  5.0    121.318182
#  4.7    120.416667
#  4.8    118.971429
#  3.3    117.869565
#  3.6    112.830986
#  4.3    112.500000
#  4.1    112.215278
#  3.7    110.541667
# -1.0    108.988189
#  3.1    108.575521
#  4.2    107.642857
#  4.5    105.402778
#  2.9    101.928571
#  4.4     89.772727
# Industry
#                                                    avg_salary
# Industry
# Industry\nConstruction                             190.000000
# Industry\nInternet & Web Services                  151.250000
# Industry\nEnergy & Utilities                       150.000000
# Type\nSelf-employed                                134.000000
# Type\nSchool / School District                     125.000000
# Industry\nCivic & Social Services                  122.666667
# Industry\nArchitectural & Engineering Services     121.500000
# Type\nCompany - Public                             120.637019
# ...

# %%
df.pivot_table(index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                                               0     1
# Revenue
# -1                                                  137.0  29.0
# Revenue\n$1 to $5 million (USD)                       6.0   2.0
# Revenue\n$100 to $500 million (USD)                   3.0   NaN
# Revenue\n$25 to $100 million (USD)                    5.0   NaN
# Revenue\n$5 to $25 million (USD)                     15.0   NaN
# Revenue\n$500 million to $1 billion (USD)             1.0   NaN
# Revenue\nLess than $1 million (USD)                   4.0   9.0
# Revenue\nUnknown / Non-Applicable                    33.0   2.0
# Sector\nAerospace & Defense                          18.0   4.0
# Sector\nAgriculture                                   1.0   1.0
# Sector\nArts, Entertainment & Recreation             14.0   NaN
# Sector\nConstruction, Repair & Maintenance Serv...    3.0   NaN
# Sector\nEducation                                    24.0   2.0
# Sector\nEnergy, Mining & Utilities                   16.0   1.0
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords") 
nltk.download('punkt')

from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
#from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Valde\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Valde\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv')
